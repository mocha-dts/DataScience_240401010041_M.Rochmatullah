# %% [markdown]
# <a href="https://colab.research.google.com/github/mocha-dts/DataScience_240401010041_M.Rochmatullah/blob/main/Pertemuan1_MochamadRochmatullah_240401010041.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Nama Lengkap  : Mochamad Rochmatullah
# #### NIM           : 240401010041
# #### Kelas         : IF403

# %% [markdown]
# # **Sesi 1 – Pengenalan Data Science**

# %% [markdown]
# #### SEL 1: Output sederhana

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# #### SEL 2: Variabel dan tipe data dasar

# %%
nama = "Mochamad Rochmatullah" # String
angkatan = 2024 # Integer
ipk = 3.75 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mochamad Rochmatullah
# Angkatan: 2024
# IPK : 3.75
# Aktif : True

# %% [markdown]
# #### SEL 3: List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
 print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %% [markdown]
# #### SEL 4: Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
 """Fungsi untuk menampilkan perkenalan mahasiswa."""
 return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Mochamad Rochmatullah", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Mochamad Rochmatullah dari Informatika, angkatan 2024.

# %% [markdown]
# ---
#
#
# #### Kesimpulan
#
# ---

# %% [markdown]
# <p>Pada pertemuan pertama ini, saya mempelajari konsep dasar Data Science sebagai bidang multidisiplin yang menggabungkan statistika, ilmu komputer, dan pengetahuan domain untuk mengekstraksi informasi serta wawasan dari data. Selain itu, saya memahami berbagai peran dalam ekosistem Data Science, seperti Data Analyst, Data Scientist, dan Machine Learning Engineer, serta mempelajari kerangka kerja CRISP-DM yang digunakan sebagai panduan dalam menjalankan proyek Data Science. Saya juga mengenal berbagai tools pendukung seperti Python, Google Colab, Jupyter Notebook, dan GitHub yang menjadi bagian penting dalam proses pembelajaran dan pengembangan proyek data.</br></br>
# <p>Temuan utama yang saya peroleh adalah bahwa keberhasilan proyek Data Science tidak hanya bergantung pada kemampuan teknis, tetapi juga pada pemahaman masalah bisnis dan kualitas data yang digunakan. Saya juga memahami bahwa Data Science memiliki prospek karier yang sangat luas dan terus berkembang seiring meningkatnya kebutuhan industri terhadap pengambilan keputusan berbasis data.
